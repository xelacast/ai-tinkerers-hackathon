# %%
from twelvelabs import TwelveLabs
import os

# %%
client = TwelveLabs(api_key=os.getenv('TL_API_KEY'))

# %% [markdown]
# # Get Index Search Results

# %%
search_results = client.search.query(
  index_id="66abefd2dde98afa0afb285b",
  query_text="A man cooking a steak",
  options=["visual", "conversation"]
)

# Utility function to print a specific page
def print_page(page):
  for clip in page:
    print(
        f" video_id={clip.video_id} score={clip.score} start={clip.start} end={clip.end} confidence={clip.confidence}"
    )

print_page(search_results.data)

while True:
    try:
        print_page(next(search_results))
    except StopIteration:
        break
# Out:
#  video_id=66ae779d7b2deac81dd1284c score=88.48 start=455.91666666681374 end=481.91666666681374 confidence=high
#  video_id=66ae779d7b2deac81dd1284c score=88.35 start=10.66666666666664 end=24.66666666666664 confidence=high
#  video_id=66ae779d7b2deac81dd1284c score=86.78 start=112.86666666666532 end=171.24999999999284 confidence=high
#  video_id=66ae779d7b2deac81dd1284c score=86.77 start=427.783333333458 end=451.8333333334772 confidence=high
#  video_id=66ae779d7b2deac81dd1284c score=86.76 start=0.0 end=4.966666666666659 confidence=high
#  video_id=66ae779d7b2deac81dd1284c score=86.75 start=217.94999999999015 end=265.2999999999954 confidence=high
#  video_id=66ae779d7b2deac81dd1284c score=86.73 start=268.8666666666649 end=371.58333333340533 confidence=high
#  video_id=66ae779d7b2deac81dd1284c score=86.71 start=543.4500000001631 end=586.4833333334573 confidence=high
#  video_id=66ae779d7b2deac81dd1284c score=86.69 start=380.2083333334162 end=410.4750000001002 confidence=high
#  video_id=66ae779d7b2deac81dd1284c score=86.48 start=412.1166666667733 end=421.40000000011963 confidence=high
#  video_id=66ae779d7b2deac81dd1284c score=85.97 start=63.66666666666561 end=94.86666666666532 confidence=high
#  video_id=66ae779d7b2deac81dd1284c score=85.95 start=481.91666666681374 end=543.4500000001631 confidence=high
#  video_id=66ae779d7b2deac81dd1284c score=85.88 start=4.966666666666659 end=10.66666666666664 confidence=high
#  video_id=66ae779d7b2deac81dd1284c score=85.81 start=265.2999999999954 end=268.8666666666649 confidence=high
#  video_id=66ae779d7b2deac81dd1284c score=85.75 start=42.66666666666664 end=63.66666666666561 confidence=high
#  video_id=66ae779d7b2deac81dd1284c score=85.7 start=214.0333333333238 end=217.94999999999015 confidence=high
#  video_id=66ae779d7b2deac81dd1284c score=85.69 start=24.66666666666664 end=28.66666666666664 confidence=high
#  video_id=66ae779d7b2deac81dd1284c score=85.58 start=410.4750000001002 end=412.1166666667733 confidence=high
#  video_id=66ae779d7b2deac81dd1284c score=85.55 start=421.40000000011963 end=425.5916666667888 confidence=high
#  video_id=66ae779d7b2deac81dd1284c score=85.53 start=100.86666666666532 end=112.86666666666532 confidence=high
#  video_id=66ae779d7b2deac81dd1284c score=85.41 start=371.58333333340533 end=380.2083333334162 confidence=high
#  video_id=66ae779d7b2deac81dd1284c score=85.37 start=451.8333333334772 end=455.91666666681374 confidence=high
#  video_id=66ae779d7b2deac81dd1284c score=85.32 start=171.24999999999284 end=178.0333333333258 confidence=high
#  video_id=66ae779d7b2deac81dd1284c score=85.08 start=190.89999999999173 end=197.06666666665805 confidence=high
#  video_id=66ae779d7b2deac81dd1284c score=84.88 start=197.06666666665805 end=214.0333333333238 confidence=high
#  video_id=66ae779d7b2deac81dd1284c score=84.74 start=28.66666666666664 end=42.66666666666664 confidence=high
#  video_id=66ae779d7b2deac81dd1284c score=84.72 start=425.5916666667888 end=427.783333333458 confidence=high
#  video_id=66ae779d7b2deac81dd1284c score=84.59 start=94.86666666666532 end=100.86666666666532 confidence=high
#  video_id=66ae779d7b2deac81dd1284c score=84.41 start=593.6111111111916 end=602.0 confidence=high
#  video_id=66ae779d7b2deac81dd1284c score=84.23 start=178.0333333333258 end=190.89999999999173 confidence=high
#  video_id=66ae779d7b2deac81dd1284c score=83.81 start=586.4833333334573 end=589.9666666667874 confidence=high
#  video_id=66ae779d7b2deac81dd1284c score=80.83 start=589.9666666667874 end=593.6111111111916 confidence=medium

# %%
def get_twelvelabs_generate_text_from_video():

  video_id = "66ae779d7b2deac81dd1284c"

  text_stream = client.generate.text_stream(
      video_id=video_id, prompt=""""
  Extract the ingredients and the instructions from this video.

  Make sure instructions are in sequential order from start to finish

  Use this json format as Structured Data.
  {
    "title": "title",
    "dishName": "dishName",
    "ingredients": [
      {
        "item": "item",
        "amount": "2",
        "unit": "unit"
      }
    ],
    "instructions": [
      {
        "number": "1",
        "instruction": "instruction"
      }
    ]
  }


  If there is no information leave blank.

  DO NOT RETURN ANYTHING OTHER THAN THE JSON."""
  )
  for text in text_stream:
        print(text)
  # return text_stream.aggregated_text

print(f"Aggregated text: {get_twelvelabs_generate_text_from_video()}")
# Out:
# ```json
# {
#
#  "title": "Gr
# illed Tomahawk Steak
# ",
#   "dishName
# ": "Tomahawk
#  Steak",
#   "ingredients
# ": [
#     {
#
#       "item": "
# Tomahawk Steak",
#
#       "amount":
#  "1",
#       "
# unit": "piece"
#
#     },
#     {
#
#  "item": "Salt
# ",
#       "amount":
#  "to taste",
#
#  "unit": "unit
# "
#     },
#     {
#
#       "item": "
# Pepper",
#
#  "amount": "to
#  taste",
#       "unit
# ": "unit"
#
#  },
#     {
#       "
# item": "Garlic
#  Powder",
#       "amount
# ": "to taste",
#
#       "unit": "
# unit"
#     },
#
#  {
#
#       "item": "
# Onion Powder",
#
#  "amount": "to
#  taste",
#       "unit
# ": "unit"
#
#  },
#     {
#       "
# item": "Olive
#  Oil",
#       "amount
# ": "1",
#
#  "unit
# ": "tbsp"
#
#     }
#   ],
#
#  "instructions": [
#
#  {
#       "number":
#  "1",
#       "
# instruction": "Preheat
#  grill to high heat."
#
#     },
#     {
#
#  "number": "2
# ",
#       "instruction":
#  "Season the steak with
#  salt, pepper, garlic
#  powder, and onion powder
# ."
#     },
#     {
#
#       "number": "
# 3",
#       "instruction
# ": "
# Brush steak with olive oil
# ."
#     },
#     {
#
#       "number": "
# 4",
#       "instruction
# ": "Place the steak
#  on the grill and cook
#  for 4-
# 5 minutes per side."
#
#     },
#     {
#
#  "number": "5
# ",
#       "instruction":
#  "Let the steak rest
#  for 5-10
#  minutes before slicing."
#
#  },
#     {
#       "
# number": "6",
#
#       "
# instruction": "Slice and
#  serve."
#     }
#
#  ]
# }
# ```
# Aggregated text: None

# %%
# convert output to json
